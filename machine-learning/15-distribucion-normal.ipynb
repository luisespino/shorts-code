# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

# 1. Datos aleatorios
np.random.seed(42)
n_samples = 100
n_features = 4

# Features aleatorias
X = np.random.randn(n_samples, n_features)

# Etiquetas aleatorias
y = np.random.randint(0, 2, size=n_samples)

# 2. Entrenar modelo
nb = GaussianNB()
nb.fit(X, y)

y_pred = nb.predict(X)
accuracy = accuracy_score(y, y_pred)
print(f"Precisión del modelo: {accuracy * 100:.2f}%")
# Out:
# Precisión del modelo: 70.00%

# %%
import matplotlib.pyplot as plt

probs = nb.predict_proba(X)

plt.figure(figsize=(2.6, 2))
plt.hist(probs[:, 0], bins=10, alpha=0.6, \
         label='0', color='r', edgecolor='k')
plt.hist(probs[:, 1], bins=10, alpha=0.6, \
         label='1', color='b', edgecolor='k')
plt.title("Distribución de probabilidades")
plt.xlabel("Probabilidad")
plt.ylabel("Frecuencia")
plt.legend()
plt.grid(True)

plt.show()
