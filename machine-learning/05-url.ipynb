# %%
import matplotlib.pyplot as plt
import pandas as pd

url = 'https://raw.githubusercontent.com/luisespino/shorts-code/refs/heads/main/machine-learning/05-url.csv'
df = pd.read_csv(url)

x = df['col1']
y = df['col2']

plt.scatter(x, y)
plt.show()
